# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from simulation.simulation import parallelized_simulation_attack_obs as parallelized_simulation
from attack.attack import mad_fgsm, mad_pgd
from NeuralShield.AAAI21.models import loader
from NeuralShield.hyperparameter import benchmarks

# %%
import ray
_ = ray.init(num_cpus=50, num_gpus=1)
# Out:
# 2020-11-05 21:26:36,343	INFO resource_spec.py:212 -- Starting Ray with 156.3 GiB memory available for workers and up to 70.99 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-11-05 21:26:36,592	WARNING services.py:923 -- Redis failed to start, retrying now.
# 2020-11-05 21:26:36,995	INFO services.py:1165 -- View the Ray dashboard at localhost:8265

# %% [markdown]
# # Attack with MAD
#
# [paper link](https://arxiv.org/pdf/2003.08938.pdf)
#
# The loss function here is
# $$
# \begin{aligned}
# \underset{\hat{s} \in B(s)}{\arg \min } L_{\mathrm{MAD}}(\hat{s}) &=\underset{\hat{s} \in B(s)}{\arg \max } D_{\mathrm{KL}}(\pi(\cdot \mid s) \| \pi(\cdot \mid \hat{s})) \\
# &=\underset{\hat{s} \in B(s)}{\arg \max }\left(\pi_{\theta_{\pi}}(s)-\pi_{\theta_{\pi}}(\hat{s})\right)^{\top} \Sigma^{-1}\left(\pi_{\theta_{\pi}}(s)-\pi_{\theta_{\pi}}(\hat{s})\right)
# \end{aligned}
# $$
#
# We use FGSM and PGD, instead of SGLD mentioned in paper, but it can also reduce the reward significantly.

# %%
baseline_res = {}
for env_name in benchmarks:
    if "BulletEnv" in env_name:
        for algo in benchmarks[env_name]["algos"]:
            if "a2c" in algo or "ppo" in algo:
                actor_net = loader.get_actor_net(env_name, algo)
                ret = parallelized_simulation(env_name, algo, actor_net, None, 1000,
                                        1000, None, 0, None, thread_number=50)
                baseline_res[f"{env_name}/{algo}"] = ret
# Out:
# (pid=45743) pybullet build time: Sep  4 2020 23:44:26
# (pid=45717) pybullet build time: Sep  4 2020 23:44:26
# (pid=45760) pybullet build time: Sep  4 2020 23:44:26
# (pid=45720) pybullet build time: Sep  4 2020 23:44:26
# (pid=45758) pybullet build time: Sep  4 2020 23:44:26
# (pid=45755) pybullet build time: Sep  4 2020 23:44:26
# (pid=45754) pybullet build time: Sep  4 2020 23:44:26
# (pid=45718) pybullet build time: Sep  4 2020 23:44:26
# (pid=45725) pybullet build time: Sep  4 2020 23:44:26
# (pid=45736) pybullet build time: Sep  4 2020 23:44:26
# (pid=45702) pybullet build time: Sep  4 2020 23:44:26
# (pid=45756) pybullet build time: Sep  4 2020 23:44:26
# (pid=45753) pybullet build time: Sep  4 2020 23:44:26
# (pid=45738) pybullet build time: Sep  4 2020 23:44:26
# (pid=45759) pybullet build time: Sep  4 2020 23:44:26
# (pid=45742) pybullet build time: Sep  4 2020 23:44:26
# (pid=45721) pybullet build time: Sep  4 2020 23:44:26
# (pid=45719) pybullet build time: Sep  4 2020 23:44:26
# (pid=45745) pybullet build time: Sep  4 2020 23:44:26
# (pid=45740) pybullet build time: Sep  4 2020 23:44:26
# (pid=45737) pybullet build time: Sep  4 2020 23:44:26
# (pid=45709) pybullet build time: Sep  4 2020 23:44:26
# (pid=45727) pybullet build time: Sep  4 2020 23:44:26
# (pid=45744) pybullet build time: Sep  4 2020 23:44:26
# (pid=45734) pybullet build time: Sep  4 2020 23:44:26
# (pid=45739) pybullet build time: Sep  4 2020 23:44:26
# (pid=45704) pybullet build time: Sep  4 2020 23:44:26
# (pid=45728) pybullet build time: Sep  4 2020 23:44:26
# (pid=45735) pybullet build time: Sep  4 2020 23:44:26
# (pid=45726) pybullet build time: Sep  4 2020 23:44:26
# (pid=45714) pybullet build time: Sep  4 2020 23:44:26
# (pid=45712) pybullet build time: Sep  4 2020 23:44:26
# (pid=45733) pybullet build time: Sep  4 2020 23:44:26
# (pid=45729) pybullet build time: Sep  4 2020 23:44:26
# (pid=45713) pybullet build time: Sep  4 2020 23:44:26
# (pid=45761) pybullet build time: Sep  4 2020 23:44:26
# (pid=45746) pybullet build time: Sep  4 2020 23:44:26
# (pid=45710) pybullet build time: Sep  4 2020 23:44:26
# (pid=45716) pybullet build time: Sep  4 2020 23:44:26
# (pid=45723) pybullet build time: Sep  4 2020 23:44:26
# (pid=45731) pybullet build time: Sep  4 2020 23:44:26
# (pid=45757) pybullet build time: Sep  4 2020 23:44:26
# (pid=45724) pybullet build time: Sep  4 2020 23:44:26
# (pid=45703) pybullet build time: Sep  4 2020 23:44:26
# (pid=45747) pybullet build time: Sep  4 2020 23:44:26
# (pid=45732) pybullet build time: Sep  4 2020 23:44:26
# (pid=45730) pybullet build time: Sep  4 2020 23:44:26
# (pid=45722) pybullet build time: Sep  4 2020 23:44:26
# (pid=45748) pybullet build time: Sep  4 2020 23:44:26
# (pid=45715) pybullet build time: Sep  4 2020 23:44:26

# %% [markdown]
# Attack with $l_{\infty} = 0.5$, and we attack on every observation.

# %%
fgsm_res = {}   
for env_name in benchmarks:
    if "BulletEnv" in env_name:
        for algo in benchmarks[env_name]["algos"]:
            if "a2c" in algo or "ppo" in algo:
                actor_net = loader.get_actor_net(env_name, algo)
                ret = parallelized_simulation(env_name, algo, actor_net, None, 1000,
                                        1000, mad_fgsm, 1, {"l_inf_norm": 5e-1}, thread_number=50)
                fgsm_res[f"{env_name}/{algo}"] = ret

# %%
pgd_res = {}
for env_name in benchmarks:
    if "BulletEnv" in env_name:
        for algo in benchmarks[env_name]["algos"]:
            if "a2c" in algo or "ppo" in algo:
                actor_net = loader.get_actor_net(env_name, algo)
                ret = parallelized_simulation(env_name, algo, actor_net, None, 1000,
                                        1000, mad_pgd, 1, {"l_inf_norm": 5e-1, "lr": 1e-1}, thread_number=50)
                pgd_res[f"{env_name}/{algo}"] = ret

# %%
baseline_df = pd.DataFrame.from_dict(baseline_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
baseline_df.insert(3, "attack", None)

df_fgsm = pd.DataFrame.from_dict(fgsm_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
df_fgsm.insert(3, "attack", "MAD-FGSM")

df_pgd = pd.DataFrame.from_dict(pgd_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
df_pgd.insert(3, "attack", "MAD-PGD")

df3 = pd.concat([baseline_df, df_fgsm, df_pgd])

df3.to_csv("res/mad_obs_attack_0.5.csv")

# %% [markdown]
# With attacks, the reward decreased significantly, but these attacks does not cause any unsafe trajectory.

# %%
df3.sort_index()
# Out:
#                                       reward mean   reward std  \
# AntBulletEnv-v0/a2c_norm              2275.409203    78.214526
# AntBulletEnv-v0/a2c_norm               772.703955    64.062102
# AntBulletEnv-v0/a2c_norm               895.455374    80.011208
# AntBulletEnv-v0/ppo2_norm             2203.950433   154.262919
# AntBulletEnv-v0/ppo2_norm             1628.068648   267.301124
# AntBulletEnv-v0/ppo2_norm             1376.362562   296.090052
# HalfCheetahBulletEnv-v0/a2c_norm      2193.813466    84.030010
# HalfCheetahBulletEnv-v0/a2c_norm      2200.374856    83.379577
# HalfCheetahBulletEnv-v0/a2c_norm      2196.015145    80.585623
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2971.039425   173.436992
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2968.398803   190.913202
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2961.009684   199.144544
# HopperBulletEnv-v0/a2c_norm           1272.853434  1090.976669
# HopperBulletEnv-v0/a2c_norm           1303.178915  1072.986605
# HopperBulletEnv-v0/a2c_norm           1299.023649  1084.506697
# HopperBulletEnv-v0/ppo2_norm          1688.482828   998.985605
# HopperBulletEnv-v0/ppo2_norm          1701.838172   954.279033
# HopperBulletEnv-v0/ppo2_norm          1731.478851   953.592824
# HumanoidBulletEnv-v0/ppo2_norm         257.313154    71.268620
# HumanoidBulletEnv-v0/ppo2_norm         566.949227  1721.221748
# HumanoidBulletEnv-v0/ppo2_norm         258.292175    73.889834
#
#                                       unsafe states found    attack
# AntBulletEnv-v0/a2c_norm                              0.0      None
# AntBulletEnv-v0/a2c_norm                              0.0   MAD-PGD
# AntBulletEnv-v0/a2c_norm                              0.0  MAD-FGSM
# AntBulletEnv-v0/ppo2_norm                             0.0      None
# AntBulletEnv-v0/ppo2_norm                             0.0   MAD-PGD
# AntBulletEnv-v0/ppo2_norm                             0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0      None
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0   MAD-PGD
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0   MAD-PGD
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0      None
# HopperBulletEnv-v0/a2c_norm                           0.0  MAD-FGSM
# HopperBulletEnv-v0/a2c_norm                           0.0      None
# HopperBulletEnv-v0/a2c_norm                           0.0   MAD-PGD
# HopperBulletEnv-v0/ppo2_norm                          0.0  MAD-FGSM
# HopperBulletEnv-v0/ppo2_norm                          0.0      None
# HopperBulletEnv-v0/ppo2_norm                          0.0   MAD-PGD
# HumanoidBulletEnv-v0/ppo2_norm                        0.0  MAD-FGSM
# HumanoidBulletEnv-v0/ppo2_norm                        0.0      None
# HumanoidBulletEnv-v0/ppo2_norm                        0.0   MAD-PGD

# %% [markdown]
# Attack with $l_{\infty} = 1$, and we attack on every observation.

# %%
fgsm_res = {}   
for env_name in benchmarks:
    if "BulletEnv" in env_name:
        for algo in benchmarks[env_name]["algos"]:
            if "a2c" in algo or "ppo" in algo:
                actor_net = loader.get_actor_net(env_name, algo)
                ret = parallelized_simulation(env_name, algo, actor_net, None, 1000,
                                        1000, mad_fgsm, 1, {"l_inf_norm": 1}, thread_number=50)
                fgsm_res[f"{env_name}/{algo}"] = ret

# %%
pgd_res = {}
for env_name in benchmarks:
    if "BulletEnv" in env_name:
        for algo in benchmarks[env_name]["algos"]:
            if "a2c" in algo or "ppo" in algo:
                actor_net = loader.get_actor_net(env_name, algo)
                ret = parallelized_simulation(env_name, algo, actor_net, None, 1000,
                                        1000, mad_pgd, 1, {"l_inf_norm": 1, "lr": 1e-1}, thread_number=50)
                pgd_res[f"{env_name}/{algo}"] = ret

# %%
baseline_df = pd.DataFrame.from_dict(baseline_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
baseline_df.insert(3, "attack", None)

df_fgsm = pd.DataFrame.from_dict(fgsm_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
df_fgsm.insert(3, "attack", "MAD-FGSM")

df_pgd = pd.DataFrame.from_dict(pgd_res, orient="index", columns=["reward mean", "reward std", "unsafe states found"])
df_pgd.insert(3, "attack", "MAD-PGD")

df3 = pd.concat([baseline_df, df_fgsm, df_pgd])

df3.to_csv("res/mad_obs_attack_1.0.csv")
df3.sort_index()
# Out:
#                                       reward mean   reward std  \
# AntBulletEnv-v0/a2c_norm              2275.409203    78.214526
# AntBulletEnv-v0/a2c_norm               747.739234    61.512710
# AntBulletEnv-v0/a2c_norm               668.541822   102.158943
# AntBulletEnv-v0/ppo2_norm             2203.950433   154.262919
# AntBulletEnv-v0/ppo2_norm             1560.970516   255.385187
# AntBulletEnv-v0/ppo2_norm              833.033551    87.172706
# HalfCheetahBulletEnv-v0/a2c_norm      2193.813466    84.030010
# HalfCheetahBulletEnv-v0/a2c_norm      2197.209051    83.773720
# HalfCheetahBulletEnv-v0/a2c_norm      2198.444688    90.911089
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2945.853646   207.171035
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2952.706469   198.308285
# HalfCheetahBulletEnv-v0/ppo2_norm_tw  2961.009684   199.144544
# HopperBulletEnv-v0/a2c_norm           1263.563238  1092.157755
# HopperBulletEnv-v0/a2c_norm           1303.178915  1072.986605
# HopperBulletEnv-v0/a2c_norm           1272.489944  1074.195161
# HopperBulletEnv-v0/ppo2_norm          1682.089950   996.202295
# HopperBulletEnv-v0/ppo2_norm          1701.838172   954.279033
# HopperBulletEnv-v0/ppo2_norm          1645.989121  1028.323056
# HumanoidBulletEnv-v0/ppo2_norm         253.273240    73.364580
# HumanoidBulletEnv-v0/ppo2_norm         566.949227  1721.221748
# HumanoidBulletEnv-v0/ppo2_norm         259.938071    73.006259
#
#                                       unsafe states found    attack
# AntBulletEnv-v0/a2c_norm                              0.0      None
# AntBulletEnv-v0/a2c_norm                              0.0   MAD-PGD
# AntBulletEnv-v0/a2c_norm                              0.0  MAD-FGSM
# AntBulletEnv-v0/ppo2_norm                             0.0      None
# AntBulletEnv-v0/ppo2_norm                             0.0   MAD-PGD
# AntBulletEnv-v0/ppo2_norm                             0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0      None
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0   MAD-PGD
# HalfCheetahBulletEnv-v0/a2c_norm                      0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0   MAD-PGD
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0  MAD-FGSM
# HalfCheetahBulletEnv-v0/ppo2_norm_tw                  0.0      None
# HopperBulletEnv-v0/a2c_norm                           0.0  MAD-FGSM
# HopperBulletEnv-v0/a2c_norm                           0.0      None
# HopperBulletEnv-v0/a2c_norm                           0.0   MAD-PGD
# HopperBulletEnv-v0/ppo2_norm                          0.0  MAD-FGSM
# HopperBulletEnv-v0/ppo2_norm                          0.0      None
# HopperBulletEnv-v0/ppo2_norm                          0.0   MAD-PGD
# HumanoidBulletEnv-v0/ppo2_norm                        0.0  MAD-FGSM
# HumanoidBulletEnv-v0/ppo2_norm                        0.0      None
# HumanoidBulletEnv-v0/ppo2_norm                        0.0   MAD-PGD
